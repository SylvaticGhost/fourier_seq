# %%
import numpy as np

T = 2*np.pi
w = 2*np.pi/T
N= 3

# %%
import sympy as sp
x = sp.symbols('x')
n = sp.symbols('n', integer=True)

# f_input = sp.sin(x) + sp.cos(2*x)
f_input = sp.Piecewise(
    (sp.sin(x), (x % (2 * np.pi) <= np.pi) & (x % (2 * np.pi) >= 0)),
    (0, True)
)

f = sp.lambdify(x, f_input)
print(f'f = {f_input}')
# Out:
# f = Piecewise((sin(x), Mod(1.0*x, 6.28318530717959) <= 3.14159265358979), (0, True))

# %%
import matplotlib.pyplot as plt

d = 1000
x_val = np.linspace(0 - 2*T, 0 + 2*T, d)

y = [f(i) for i in x_val]

plt.plot(x_val, y)
plt.grid(linewidth=1)
plt.show()

# %%
a0 = 1/T*sp.integrate(f_input, (x, -T/2, T/2))
print(f'a0 = {a0}')

an = 2/T*sp.integrate(f_input*sp.cos(n*w*x), (x, -T/2, T/2))
# print(f'an = {an}')

bn = 2/T*sp.integrate(f_input*sp.sin(n*w*x), (x, -T/2, T/2))
# print(f'bn = {bn}')

fourier = a0 + sp.Sum(an*sp.cos(n*w*x) + bn*sp.sin(n*w*x), (n, 1, N))
# print(f'fourier = {fourier}')

y_fourier = [fourier.subs(x, i) for i in x_val]
plt.plot(x_val, y_fourier)
plt.grid(linewidth=1)
plt.show()
# Out:
# a0 = 0.159154943091895*Integral(Piecewise((sin(x), Mod(1.0*x, 6.28318530717959) <= 3.14159265358979), (0, True)), (x, -3.14159265358979, 3.14159265358979))
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\miniconda3\Lib\site-packages\sympy\core\evalf.py:1335, in evalf_sum(expr, prec, options)
#    1334 if b is not S.Infinity or a is S.NegativeInfinity or a != int(a):
# -> 1335     raise NotImplementedError
#    1336 # Use fast hypergeometric summation if possible
#
# NotImplementedError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 14
#      11 # print(f'fourier = {fourier}')
#      13 y_fourier = [fourier.subs(x, i) for i in x_val]
# ---> 14 plt.plot(x_val, y_fourier)
#      15 plt.grid(linewidth=1)
#      16 plt.show()
#
# File ~\miniconda3\Lib\site-packages\matplotlib\pyplot.py:3794, in plot(scalex, scaley, data, *args, **kwargs)
#    3786 @_copy_docstring_and_deprecators(Axes.plot)
#    3787 def plot(
#    3788     *args: float | ArrayLike | str,
#    (...)
#    3792     **kwargs,
#    3793 ) -> list[Line2D]:
# -> 3794     return gca().plot(
#    3795         *args,
#    3796         scalex=scalex,
#    3797         scaley=scaley,
#    3798         **({"data": data} if data is not None else {}),
#    3799         **kwargs,
#    3800     )
#
# File ~\miniconda3\Lib\site-packages\matplotlib\axes\_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1536 """
#    1537 Plot y versus x as lines and/or markers.
#    1538
#    (...)
#    1776 (``'green'``) or hex strings (``'#008000'``).
#    1777 """
#    1778 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1779 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1780 for line in lines:
#    1781     self.add_line(line)
#
# File ~\miniconda3\Lib\site-packages\matplotlib\axes\_base.py:296, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     294     this += args[0],
#     295     args = args[1:]
# --> 296 yield from self._plot_args(
#     297     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\miniconda3\Lib\site-packages\matplotlib\axes\_base.py:483, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     481     axes.xaxis.update_units(x)
#     482 if axes.yaxis is not None:
# --> 483     axes.yaxis.update_units(y)
#     485 if x.shape[0] != y.shape[0]:
#     486     raise ValueError(f"x and y must have same first dimension, but "
#     487                      f"have shapes {x.shape} and {y.shape}")
#
# File ~\miniconda3\Lib\site-packages\matplotlib\axis.py:1750, in Axis.update_units(self, data)
#    1744 def update_units(self, data):
#    1745     """
#    1746     Introspect *data* for units converter and update the
#    1747     ``axis.converter`` instance if necessary. Return *True*
#    1748     if *data* is registered for unit conversion.
#    1749     """
# -> 1750     converter = munits.registry.get_converter(data)
#    1751     if converter is None:
#    1752         return False
#
# File ~\miniconda3\Lib\site-packages\matplotlib\units.py:183, in Registry.get_converter(self, x)
#     181         pass
#     182 try:  # If cache lookup fails, look up based on first element...
# --> 183     first = cbook._safe_first_finite(x)
#     184 except (TypeError, StopIteration):
#     185     pass
#
# File ~\miniconda3\Lib\site-packages\matplotlib\cbook.py:1782, in _safe_first_finite(obj)
#    1780 else:
#    1781     for val in obj:
# -> 1782         if safe_isfinite(val):
#    1783             return val
#    1784     return safe_first_element(obj)
#
# File ~\miniconda3\Lib\site-packages\matplotlib\cbook.py:1762, in _safe_first_finite.<locals>.safe_isfinite(val)
#    1760     return False
#    1761 try:
# -> 1762     return math.isfinite(val)
#    1763 except (TypeError, ValueError):
#    1764     # if the outer object is 2d, then val is a 1d array, and
#    1765     # - math.isfinite(numpy.zeros(3)) raises TypeError
#    1766     # - math.isfinite(torch.zeros(3)) raises ValueError
#    1767     pass
#
# File ~\miniconda3\Lib\site-packages\sympy\core\expr.py:335, in Expr.__float__(self)
#     331 def __float__(self):
#     332     # Don't bother testing if it's a number; if it's not this is going
#     333     # to fail, and if it is we still need to check that it evalf'ed to
#     334     # a number.
# --> 335     result = self.evalf()
#     336     if result.is_Number:
#     337         return float(result)
#
# File ~\miniconda3\Lib\site-packages\sympy\core\evalf.py:1648, in EvalfMixin.evalf(self, n, subs, maxn, chop, strict, quad, verbose)
#    1646     options['quad'] = quad
#    1647 try:
# -> 1648     result = evalf(self, prec + 4, options)
#    1649 except NotImplementedError:
#    1650     # Fall back to the ordinary evalf
#    1651     if hasattr(self, 'subs') and subs is not None:  # issue 20291
#
# File ~\miniconda3\Lib\site-packages\sympy\core\evalf.py:1483, in evalf(x, prec, options)
#    1481 try:
#    1482     rf = evalf_table[type(x)]
# -> 1483     r = rf(x, prec, options)
#    1484 except KeyError:
#    1485     # Fall back to ordinary evalf if possible
#    1486     if 'subs' in options:
#
# File ~\miniconda3\Lib\site-packages\sympy\core\evalf.py:601, in evalf_add(v, prec, options)
#     598 while 1:
#     599     options['maxprec'] = min(oldmaxprec, 2*prec)
# --> 601     terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     602     n = terms.count(S.ComplexInfinity)
#     603     if n >= 2:
#
# File ~\miniconda3\Lib\site-packages\sympy\core\evalf.py:1483, in evalf(x, prec, options)
#    1481 try:
#    1482     rf = evalf_table[type(x)]
# -> 1483     r = rf(x, prec, options)
#    1484 except KeyError:
#    1485     # Fall back to ordinary evalf if possible
#    1486     if 'subs' in options:
#
# File ~\miniconda3\Lib\site-packages\sympy\core\evalf.py:1347, in evalf_sum(expr, prec, options)
#    1345 for i in range(1, 5):
#    1346     m = n = 2**i * prec
# -> 1347     s, err = expr.euler_maclaurin(m=m, n=n, eps=eps,
#    1348         eval_integral=False)
#    1349     err = err.evalf()
#    1350     if err is S.NaN:
#
# File ~\miniconda3\Lib\site-packages\sympy\concrete\summations.py:757, in Sum.euler_maclaurin(self, m, n, eps, eval_integral)
#     755 term = f.subs(i, a)
#     756 if term:
# --> 757     test = abs(term.evalf(3)) < eps
#     758     if test == True:
#     759         return s, abs(term)
#
# File ~\miniconda3\Lib\site-packages\sympy\core\evalf.py:1648, in EvalfMixin.evalf(self, n, subs, maxn, chop, strict, quad, verbose)
#    1646     options['quad'] = quad
#    1647 try:
# -> 1648     result = evalf(self, prec + 4, options)
#    1649 except NotImplementedError:
#    1650     # Fall back to the ordinary evalf
#    1651     if hasattr(self, 'subs') and subs is not None:  # issue 20291
#
# File ~\miniconda3\Lib\site-packages\sympy\core\evalf.py:1483, in evalf(x, prec, options)
#    1481 try:
#    1482     rf = evalf_table[type(x)]
# -> 1483     r = rf(x, prec, options)
#    1484 except KeyError:
#    1485     # Fall back to ordinary evalf if possible
#    1486     if 'subs' in options:
#
# File ~\miniconda3\Lib\site-packages\sympy\core\evalf.py:601, in evalf_add(v, prec, options)
#     598 while 1:
#     599     options['maxprec'] = min(oldmaxprec, 2*prec)
# --> 601     terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     602     n = terms.count(S.ComplexInfinity)
#     603     if n >= 2:
#
# File ~\miniconda3\Lib\site-packages\sympy\core\evalf.py:1483, in evalf(x, prec, options)
#    1481 try:
#    1482     rf = evalf_table[type(x)]
# -> 1483     r = rf(x, prec, options)
#    1484 except KeyError:
#    1485     # Fall back to ordinary evalf if possible
#    1486     if 'subs' in options:
#
# File ~\miniconda3\Lib\site-packages\sympy\core\evalf.py:697, in evalf_mul(v, prec, options)
#     695 elif i == last and arg is S.One:
#     696     continue
# --> 697 re, im, re_acc, im_acc = evalf(arg, working_prec, options)
#     698 if re and im:
#     699     complex_factors.append((re, im, re_acc, im_acc))
#
# File ~\miniconda3\Lib\site-packages\sympy\core\evalf.py:1483, in evalf(x, prec, options)
#    1481 try:
#    1482     rf = evalf_table[type(x)]
# -> 1483     r = rf(x, prec, options)
#    1484 except KeyError:
#    1485     # Fall back to ordinary evalf if possible
#    1486     if 'subs' in options:
#
# File ~\miniconda3\Lib\site-packages\sympy\core\evalf.py:1175, in evalf_integral(expr, prec, options)
#    1173 maxprec = options.get('maxprec', INF)
#    1174 while 1:
# -> 1175     result = do_integral(expr, workprec, options)
#    1176     accuracy = complex_accuracy(result)
#    1177     if accuracy >= prec:  # achieved desired precision
#
# File ~\miniconda3\Lib\site-packages\sympy\core\evalf.py:1136, in do_integral(expr, prec, options)
#    1134         quadrature_error = MINUS_INF
#    1135     else:
# -> 1136         result, quadrature_err = quadts(f, [xlow, xhigh], error=1)
#    1137         quadrature_error = fastlog(quadrature_err._mpf_)
#    1139 options['maxprec'] = oldmaxprec
#
# File ~\miniconda3\Lib\site-packages\mpmath\calculus\quadrature.py:789, in QuadratureMethods.quadts(ctx, *args, **kwargs)
#     768 """
#     769 Performs tanh-sinh quadrature. The call
#     770
#    (...)
#     786 tanh-sinh quadrature.
#     787 """
#     788 kwargs['method'] = 'tanh-sinh'
# --> 789 return ctx.quad(*args, **kwargs)
#
# File ~\miniconda3\Lib\site-packages\mpmath\calculus\quadrature.py:746, in QuadratureMethods.quad(ctx, f, *points, **kwargs)
#     744 ctx.prec += 20
#     745 if dim == 1:
# --> 746     v, err = rule.summation(f, points[0], prec, epsilon, m, verbose)
#     747 elif dim == 2:
#     748     v, err = rule.summation(lambda x: \
#     749             rule.summation(lambda y: f(x,y), \
#     750             points[1], prec, epsilon, m)[0],
#     751         points[0], prec, epsilon, m, verbose)
#
# File ~\miniconda3\Lib\site-packages\mpmath\calculus\quadrature.py:233, in QuadratureRule.summation(self, f, points, prec, epsilon, max_degree, verbose)
#     230 if verbose:
#     231     print("Integrating from %s to %s (degree %s of %s)" % \
#     232         (ctx.nstr(a), ctx.nstr(b), degree, max_degree))
# --> 233 result = self.sum_next(f, nodes, degree, prec, results, verbose)
#     234 results.append(result)
#     235 if degree > 1:
#
# File ~\miniconda3\Lib\site-packages\mpmath\calculus\quadrature.py:308, in TanhSinh.sum_next(self, f, nodes, degree, prec, previous, verbose)
#     306 else:
#     307     S = self.ctx.zero
# --> 308 S += self.ctx.fdot((w,f(x)) for (x,w) in nodes)
#     309 return h*S
#
# File ~\miniconda3\Lib\site-packages\mpmath\ctx_mp_python.py:938, in PythonMPContext.fdot(ctx, A, B, conjugate)
#     936 hasattr_ = hasattr
#     937 types = (ctx.mpf, ctx.mpc)
# --> 938 for a, b in A:
#     939     if type(a) not in types: a = ctx.convert(a)
#     940     if type(b) not in types: b = ctx.convert(b)
#
# File ~\miniconda3\Lib\site-packages\mpmath\calculus\quadrature.py:308, in <genexpr>(.0)
#     306 else:
#     307     S = self.ctx.zero
# --> 308 S += self.ctx.fdot((w,f(x)) for (x,w) in nodes)
#     309 return h*S
#
# File ~\miniconda3\Lib\site-packages\sympy\core\evalf.py:1109, in do_integral.<locals>.f(t)
#    1107 def f(t: 'Expr') -> tUnion[mpc, mpf]:
#    1108     nonlocal max_real_term, max_imag_term
# -> 1109     re, im, re_acc, im_acc = evalf(func, mp.prec, {'subs': {x: t}})
#    1111     have_part[0] = re or have_part[0]
#    1112     have_part[1] = im or have_part[1]
#
# File ~\miniconda3\Lib\site-packages\sympy\core\evalf.py:1483, in evalf(x, prec, options)
#    1481 try:
#    1482     rf = evalf_table[type(x)]
# -> 1483     r = rf(x, prec, options)
#    1484 except KeyError:
#    1485     # Fall back to ordinary evalf if possible
#    1486     if 'subs' in options:
#
# File ~\miniconda3\Lib\site-packages\sympy\core\evalf.py:1034, in evalf_piecewise(expr, prec, options)
#    1032 from .numbers import Float, Integer
#    1033 if 'subs' in options:
# -> 1034     expr = expr.subs(evalf_subs(prec, options['subs']))
#    1035     newopts = options.copy()
#    1036     del newopts['subs']
#
# File ~\miniconda3\Lib\site-packages\sympy\core\basic.py:1123, in Basic.subs(self, *args, **kwargs)
#    1121 rv = self
#    1122 for old, new in sequence:
# -> 1123     rv = rv._subs(old, new, **kwargs)
#    1124     if not isinstance(rv, Basic):
#    1125         break
#
# File ~\miniconda3\Lib\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\miniconda3\Lib\site-packages\sympy\core\basic.py:1235, in Basic._subs(self, old, new, **hints)
#    1232 if _aresame(self, old):
#    1233     return new
# -> 1235 rv = self._eval_subs(old, new)
#    1236 if rv is None:
#    1237     rv = fallback(self, old, new)
#
# File ~\miniconda3\Lib\site-packages\sympy\functions\elementary\piecewise.py:765, in Piecewise._eval_subs(self, old, new)
#     763 args_exist = False
#     764 for i, (e, c) in enumerate(args):
# --> 765     c = c._subs(old, new)
#     766     if c != False:
#     767         args_exist = True
#
# File ~\miniconda3\Lib\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\miniconda3\Lib\site-packages\sympy\core\basic.py:1237, in Basic._subs(self, old, new, **hints)
#    1235 rv = self._eval_subs(old, new)
#    1236 if rv is None:
# -> 1237     rv = fallback(self, old, new)
#    1238 return rv
#
# File ~\miniconda3\Lib\site-packages\sympy\core\basic.py:1209, in Basic._subs.<locals>.fallback(self, old, new)
#    1207 if not hasattr(arg, '_eval_subs'):
#    1208     continue
# -> 1209 arg = arg._subs(old, new, **hints)
#    1210 if not _aresame(arg, args[i]):
#    1211     hit = True
#
# File ~\miniconda3\Lib\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\miniconda3\Lib\site-packages\sympy\core\basic.py:1237, in Basic._subs(self, old, new, **hints)
#    1235 rv = self._eval_subs(old, new)
#    1236 if rv is None:
# -> 1237     rv = fallback(self, old, new)
#    1238 return rv
#
# File ~\miniconda3\Lib\site-packages\sympy\core\basic.py:1209, in Basic._subs.<locals>.fallback(self, old, new)
#    1207 if not hasattr(arg, '_eval_subs'):
#    1208     continue
# -> 1209 arg = arg._subs(old, new, **hints)
#    1210 if not _aresame(arg, args[i]):
#    1211     hit = True
#
# File ~\miniconda3\Lib\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\miniconda3\Lib\site-packages\sympy\core\basic.py:1237, in Basic._subs(self, old, new, **hints)
#    1235 rv = self._eval_subs(old, new)
#    1236 if rv is None:
# -> 1237     rv = fallback(self, old, new)
#    1238 return rv
#
# File ~\miniconda3\Lib\site-packages\sympy\core\basic.py:1214, in Basic._subs.<locals>.fallback(self, old, new)
#    1212         args[i] = arg
#    1213 if hit:
# -> 1214     rv = self.func(*args)
#    1215     hack2 = hints.get('hack2', False)
#    1216     if hack2 and self.is_Mul and not rv.is_Mul:  # 2-arg hack
#
# File ~\miniconda3\Lib\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\miniconda3\Lib\site-packages\sympy\core\operations.py:63, in AssocOp.__new__(cls, evaluate, _sympify, *args)
#      61 if typ is not None:
#      62     from .relational import Relational
# ---> 63     if any(isinstance(arg, Relational) for arg in args):
#      64         raise TypeError("Relational cannot be used in %s" % cls.__name__)
#      66     # This should raise TypeError once deprecation period is over:
#
# File ~\miniconda3\Lib\site-packages\sympy\core\operations.py:63, in <genexpr>(.0)
#      61 if typ is not None:
#      62     from .relational import Relational
# ---> 63     if any(isinstance(arg, Relational) for arg in args):
#      64         raise TypeError("Relational cannot be used in %s" % cls.__name__)
#      66     # This should raise TypeError once deprecation period is over:
#
# KeyboardInterrupt:
